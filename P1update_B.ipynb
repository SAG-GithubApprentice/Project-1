# %%
# Install the required libraries
# !pip install prophet
# !pip install yfinance

# %%
# Import the required libraries and dependencies
import pandas as pd
import datetime as dt
from prophet import Prophet
import hvplot.pandas
import yfinance as yf
# %matplotlib inline

# %%
sp500 = yf.Ticker('^GSPC')
sp500_hist = sp500.history(period='5y')
sp500_hist.to_csv('SP500_5y.csv')

# %%
sp500_data = pd.read_csv('SP500_5y.csv')

# %%
sp500_data.tail()
# Out:
#                            Date         Open         High          Low  \
# 1253  2024-01-30 00:00:00-05:00  4925.890137  4931.089844  4916.270020
# 1254  2024-01-31 00:00:00-05:00  4899.189941  4906.750000  4845.149902
# 1255  2024-02-01 00:00:00-05:00  4861.109863  4906.970215  4853.520020
# 1256  2024-02-02 00:00:00-05:00  4916.060059  4975.290039  4907.990234
# 1257  2024-02-05 00:00:00-05:00  4957.189941  4957.189941  4918.089844
#
#             Close      Volume  Dividends  Stock Splits
# 1253  4924.970215  3836130000        0.0           0.0
# 1254  4845.649902  4696120000        0.0           0.0
# 1255  4906.189941  4386090000        0.0           0.0
# 1256  4958.609863  3974350000        0.0           0.0
# 1257  4942.810059  2584805000        0.0           0.0

# %%
sp500_data.hvplot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %%
# Fetch historical data for WTI crude oil
crude_oil = yf.Ticker('CL=F')  # 'CL=F' is the ticker symbol for WTI crude oil
crude_oil_hist = crude_oil.history(period='5y')
# Save the data to a CSV file
crude_oil_hist.to_csv('crude_oil_5y.csv')
# Read the CSV file into a DataFrame
crude_oil_data = pd.read_csv('crude_oil_5y.csv')
crude_oil_data.tail()
# Out:
#                            Date       Open       High        Low      Close  \
# 1256  2024-01-30 00:00:00-05:00  77.019997  78.139999  75.849998  77.820000
# 1257  2024-01-31 00:00:00-05:00  77.839996  78.110001  75.519997  75.849998
# 1258  2024-02-01 00:00:00-05:00  75.959999  76.949997  73.699997  73.820000
# 1259  2024-02-02 00:00:00-05:00  73.910004  74.519997  71.790001  72.279999
# 1260  2024-02-05 00:00:00-05:00  72.760002  72.970001  72.620003  72.949997
#
#       Volume  Dividends  Stock Splits
# 1256  347242        0.0           0.0
# 1257  344493        0.0           0.0
# 1258  577936        0.0           0.0
# 1259  577936        0.0           0.0
# 1260    5006        0.0           0.0

# %%
crude_oil_data.hvplot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
# Fetch historical data for the spot price of gold
gold = yf.Ticker('GC=F')  # 'GC=F' is the ticker symbol for spot gold
gold_hist = gold.history(period='5y')
# Save the data to a CSV file
gold_hist.to_csv('gold_spot_5y.csv')
# Read the CSV file into a DataFrame
gold_data = pd.read_csv('gold_spot_5y.csv')
# Display the DataFrame
gold_data.tail()
# Out:
#                            Date         Open         High          Low  \
# 1256  2024-01-30 00:00:00-05:00  2032.500000  2048.500000  2028.099976
# 1257  2024-01-31 00:00:00-05:00  2035.400024  2055.000000  2030.000000
# 1258  2024-02-01 00:00:00-05:00  2040.199951  2064.500000  2029.000000
# 1259  2024-02-02 00:00:00-05:00  2054.800049  2055.899902  2027.699951
# 1260  2024-02-05 00:00:00-05:00  2041.400024  2044.699951  2039.900024
#
#             Close  Volume  Dividends  Stock Splits
# 1256  2031.500000   26907        0.0           0.0
# 1257  2048.399902    2007        0.0           0.0
# 1258  2053.000000     947        0.0           0.0
# 1259  2036.099976     947        0.0           0.0
# 1260  2041.599976    7371        0.0           0.0

# %%
gold_data.hvplot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
# Read the CSV files into DataFrames
sp500_data = pd.read_csv('sp500_5y.csv', index_col='Date', parse_dates=True)
crude_oil_data = pd.read_csv('crude_oil_5y.csv', index_col='Date', parse_dates=True)
gold_data = pd.read_csv('gold_spot_5y.csv', index_col='Date', parse_dates=True)
# Concatenate the three DataFrames
combined_data = pd.concat([sp500_data['Close'], crude_oil_data['Close'], gold_data['Close']], axis=1)
combined_data.columns = ['S&P 500', 'Crude Oil', 'Gold']

# %%
combined_data.hvplot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %%
# Read the data from the SP500.csv file into a Pandas DataFrame
df_SP500 = pd.read_csv('SP500.csv')

df_SP500 = pd.read_csv('sp500_5y.csv', index_col='Date', parse_dates=True)

# Review the DataFrame
df_SP500.head()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2019-02-06 00:00:00-05:00  2735.050049  2738.080078  2724.149902  2731.610107
# 2019-02-07 00:00:00-05:00  2717.530029  2719.320068  2687.260010  2706.050049
# 2019-02-08 00:00:00-05:00  2692.360107  2708.070068  2681.830078  2707.879883
# 2019-02-11 00:00:00-05:00  2712.399902  2718.050049  2703.790039  2709.800049
# 2019-02-12 00:00:00-05:00  2722.610107  2748.189941  2722.610107  2744.729980
#
#                                Volume  Dividends  Stock Splits
# Date
# 2019-02-06 00:00:00-05:00  3486590000        0.0           0.0
# 2019-02-07 00:00:00-05:00  4114040000        0.0           0.0
# 2019-02-08 00:00:00-05:00  3649510000        0.0           0.0
# 2019-02-11 00:00:00-05:00  3395330000        0.0           0.0
# 2019-02-12 00:00:00-05:00  3843020000        0.0           0.0

# %%
# Display column names for better context
df_SP500.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits'],
#       dtype='object')

# %%
# Plot the DataFrame
df_SP500.hvplot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
df_SP500.reset_index(inplace=True)

# %%
selected_columns = df_SP500[['Date', 'Close']]

# %%
df_SP500.hvplot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
selected_columns.head()
# Out:
#                         Date        Close
# 0  2019-02-06 00:00:00-05:00  2731.610107
# 1  2019-02-07 00:00:00-05:00  2706.050049
# 2  2019-02-08 00:00:00-05:00  2707.879883
# 3  2019-02-11 00:00:00-05:00  2709.800049
# 4  2019-02-12 00:00:00-05:00  2744.729980

# %%
# Reset the index of the DataFrame
prophet_df_SP500 = selected_columns.reset_index()

# Review the first and last five rows of the DataFrame
display(prophet_df_SP500.head())
display(prophet_df_SP500.tail())
# Out:
#    index                       Date        Close
# 0      0  2019-02-06 00:00:00-05:00  2731.610107
# 1      1  2019-02-07 00:00:00-05:00  2706.050049
# 2      2  2019-02-08 00:00:00-05:00  2707.879883
# 3      3  2019-02-11 00:00:00-05:00  2709.800049
# 4      4  2019-02-12 00:00:00-05:00  2744.729980
#       index                       Date        Close
# 1253   1253  2024-01-30 00:00:00-05:00  4924.970215
# 1254   1254  2024-01-31 00:00:00-05:00  4845.649902
# 1255   1255  2024-02-01 00:00:00-05:00  4906.189941
# 1256   1256  2024-02-02 00:00:00-05:00  4958.609863
# 1257   1257  2024-02-05 00:00:00-05:00  4942.810059

# %%
prophet_df_SP500.rename(columns={'Date': 'ds', 'Close': 'y'}, inplace=True)

# %%
# Prepare the training data to be read into a prophet model
# Rename the columns to names that Prophet recognizes
prophet_df_SP500.col= ['ds', 'y']
prophet_df_SP500.head()
# Out:
#    index                  ds            y
# 0      0 2019-02-06 05:00:00  2731.610107
# 1      1 2019-02-07 05:00:00  2706.050049
# 2      2 2019-02-08 05:00:00  2707.879883
# 3      3 2019-02-11 05:00:00  2709.800049
# 4      4 2019-02-12 05:00:00  2744.729980

# %%
# Initialize the Prophet model
model = Prophet()

# Fit the model with your dataframe
model.fit(prophet_df_SP500)

# Create a DataFrame for future predictions
future = model.make_future_dataframe(periods=365)  # Replace 365 with the number of periods you want to predict

# Use the model to make predictions
forecast = model.predict(future)

# The 'forecast' DataFrame now contains the forecasted values for the specified future periods
# Out:
# 19:57:13 - cmdstanpy - INFO - Chain [1] start processing
# 19:57:13 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast.tail()
# Out:
#                       ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 1618 2025-01-31 05:00:00  5526.098357  4574.857817  6580.599704  4521.051414
# 1619 2025-02-01 05:00:00  5528.214500  4630.636092  6613.840878  4518.552491
# 1620 2025-02-02 05:00:00  5530.330642  4635.990295  6687.598235  4516.053568
# 1621 2025-02-03 05:00:00  5532.446785  4599.635180  6581.391734  4513.565299
# 1622 2025-02-04 05:00:00  5534.562928  4594.395863  6620.055829  4511.179910
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 1618  6486.505830       69.096320             69.096320             69.096320
# 1619  6493.974281      104.229640            104.229640            104.229640
# 1620  6501.710294      130.766246            130.766246            130.766246
# 1621  6509.303436       79.063952             79.063952             79.063952
# 1622  6515.227592       82.342338             82.342338             82.342338
#
# ...

# %%
forecast.head()
# Out:
#                    ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0 2019-02-06 05:00:00  2778.041341  2735.890812  2990.344895  2778.041341
# 1 2019-02-07 05:00:00  2779.080927  2739.931589  2984.077580  2779.080927
# 2 2019-02-08 05:00:00  2780.120512  2741.899385  2999.169919  2780.120512
# 3 2019-02-11 05:00:00  2783.239269  2749.358333  2996.085774  2783.239269
# 4 2019-02-12 05:00:00  2784.278854  2755.018328  3004.990094  2784.278854
#
#    trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  2778.041341       84.940037             84.940037             84.940037
# 1  2779.080927       87.031995             87.031995             87.031995
# 2  2780.120512       90.826142             90.826142             90.826142
# 3  2783.239269       89.594439             89.594439             89.594439
# 4  2784.278854       88.199120             88.199120             88.199120
#
#       weekly  weekly_lower  weekly_upper      yearly  yearly_lower  \
# ...

# %%
model.plot(forecast)
# Out:
# /Users/calvarez/anaconda3/lib/python3.11/site-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /Users/calvarez/anaconda3/lib/python3.11/site-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
forecast.reset_index(inplace=True)

forecast.columns
# Out:
# Index(['index', 'ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower',
#        'trend_upper', 'additive_terms', 'additive_terms_lower',
#        'additive_terms_upper', 'weekly', 'weekly_lower', 'weekly_upper',
#        'yearly', 'yearly_lower', 'yearly_upper', 'multiplicative_terms',
#        'multiplicative_terms_lower', 'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
last_date = forecast['ds'].max()
one_year_prior = last_date - pd.DateOffset(years=1)

# Filter the dataframe
last_year_data = forecast[(forecast['ds'] >= one_year_prior) & (forecast['ds'] <= last_date)]

# Plot the data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(forecast['ds'],forecast['yhat'], label='Actual')
plt.plot(last_year_data['ds'], last_year_data['yhat'], label='Forecast')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Last Year Data')
plt.legend()
plt.show()

# %%
figures = model.plot_components(forecast)
# Out:
# /Users/calvarez/anaconda3/lib/python3.11/site-packages/prophet/plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /Users/calvarez/anaconda3/lib/python3.11/site-packages/prophet/plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# ...

# %%
forecast = forecast.set_index(["ds"])
forecast.head()
# Out:
#                      index        trend   yhat_lower   yhat_upper  \
# ds
# 2019-02-06 05:00:00      0  2778.041341  2735.890812  2990.344895
# 2019-02-07 05:00:00      1  2779.080927  2739.931589  2984.077580
# 2019-02-08 05:00:00      2  2780.120512  2741.899385  2999.169919
# 2019-02-11 05:00:00      3  2783.239269  2749.358333  2996.085774
# 2019-02-12 05:00:00      4  2784.278854  2755.018328  3004.990094
#
#                      trend_lower  trend_upper  additive_terms  \
# ds
# 2019-02-06 05:00:00  2778.041341  2778.041341       84.940037
# 2019-02-07 05:00:00  2779.080927  2779.080927       87.031995
# 2019-02-08 05:00:00  2780.120512  2780.120512       90.826142
# 2019-02-11 05:00:00  2783.239269  2783.239269       89.594439
# 2019-02-12 05:00:00  2784.278854  2784.278854       88.199120
#
#                      additive_terms_lower  additive_terms_upper     weekly  \
# ds
# 2019-02-06 05:00:00             84.940037             84.940037 -13.633031
# ...

# %%
forecast[["yhat", "yhat_lower", "yhat_upper"]].iloc[-240:, :].plot()
# Out:
# <Axes: xlabel='ds'>

# %%
forecast_feb_2020 = forecast.loc["2020-02-01":"2021-02-28"][["yhat_upper", "yhat_lower", "yhat"]]

# Replace the column names to something less technical sounding
forecast_feb_2020 = forecast_feb_2020.rename(
    columns={
        "yhat_upper": "Best Case",
        "yhat_lower": "Worst Case", 
        "yhat": "Most Likely Case"
    }
)

# Review the last five rows of the DataFrame
forecast_feb_2020.tail()
# Out:
#                        Best Case   Worst Case  Most Likely Case
# ds
# 2021-02-22 05:00:00  4062.356962  3809.745802       3935.274228
# 2021-02-23 05:00:00  4058.170453  3813.808598       3929.722807
# 2021-02-24 05:00:00  4056.090020  3797.573802       3922.470804
# 2021-02-25 05:00:00  4042.207320  3783.219519       3916.525133
# 2021-02-26 05:00:00  4036.830551  3785.548842       3912.808900

# %%
forecast_feb_2020.mean()
# Out:
# Best Case           3436.510130
# Worst Case          3183.091539
# Most Likely Case    3309.517061
# dtype: float64
